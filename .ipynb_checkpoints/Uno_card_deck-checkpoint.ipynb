# %%
import random
class Card:
#######__init__ means instatiating the object as it's created

  def __init__(self,colour,number):
  #attribute /storage
    self.colour = colour
    self.number =number
    #print(colour,number)

####### prints out the default string representation of the __main__.Card object at 0x7a8a0c679a20
####### using --str-- function to have it print in text

  def __str__(self):
        return f"{self.colour}_{self.number}"

class WildCard:
  def __init__(self, colour,action):
    self.colour = colour
    self.action = action

  def __str__(self):
    return f"{self.colour}_{self.action}"

###########  CREATE THE INITAL DECK  ########################

class Deck:
  def __init__(self):
        self.pack = []

  def create_deck(self):
        colours = ["red", "blue", "green", "yellow"]
        numbers = list(range(1, 11))
        actions = ["pick_up_2","miss_a_turn", "reverse"]
        special_wild_cards = ["wild", "pick_up_4"]


 #for number in range(1, 11):
            #self.pack.append(number)



########### ADD NORMAL CARDS ##############################
        for colour in colours:
          for number in numbers:
              new_card = Card(colour, number)
              self.pack.append(new_card)
              #print(self.pack)

########### ADD WILD CARDS ###############################

          for wild_card_type in actions:
            for colour in colours:
              for _ in range(2):
                wild_card= WildCard(colour, wild_card_type)
                self.pack.append(wild_card)


          for special_wild_card in special_wild_cards:
              for colour in colours:
                  wild_card = WildCard(colour, special_wild_card)
                  self.pack.append(wild_card)




####### SHUFFLE FUNCTION ###########

  def shuffle(self):
          random.shuffle(self.pack)
          print(self.pack)

  #######  DRAW CARD #############
  def draw_card(self):
    #if not self.is_empty():
              return self.pack.pop()

# %%
###############test area################
#test_card =Card("yellow","9")
initial_pack =Deck()
initial_pack.create_deck()
initial_pack.shuffle()
for card in initial_pack.pack:  ##show shuffled pack###
    print(card)                 ##show shuffled pack###

drawcard=initial_pack.draw_card() # Draws the top card
print(drawcard)
# Out:
# [<__main__.WildCard object at 0x7f06f4966350>, <__main__.Card object at 0x7f06c784f3a0>, <__main__.WildCard object at 0x7f06c784f130>, <__main__.WildCard object at 0x7f06f49640d0>, <__main__.WildCard object at 0x7f06f5838ca0>, <__main__.WildCard object at 0x7f06c784ee00>, <__main__.WildCard object at 0x7f06f49661d0>, <__main__.WildCard object at 0x7f06c784f160>, <__main__.Card object at 0x7f06c784fe80>, <__main__.WildCard object at 0x7f06c784e440>, <__main__.WildCard object at 0x7f06c784db10>, <__main__.WildCard object at 0x7f06f4967a30>, <__main__.Card object at 0x7f06f49657b0>, <__main__.WildCard object at 0x7f06c784dab0>, <__main__.WildCard object at 0x7f06c784d750>, <__main__.WildCard object at 0x7f06c784c880>, <__main__.WildCard object at 0x7f06f4966d10>, <__main__.WildCard object at 0x7f06c784d570>, <__main__.Card object at 0x7f06c784e050>, <__main__.Card object at 0x7f06c784cc10>, <__main__.WildCard object at 0x7f06c784e2f0>, <__main__.WildCard object at 0x7f06c784f850>, <__main__.WildCard object at 0x7f06c784e5c0>, <__main__.Card object at 0x7f06c784c490>, <__main__.WildCard object at 0x7f06c784ca60>, <__main__.Card object at 0x7f06c784fdf0>, <__main__.WildCard object at 0x7f06c784
# blue_reverse
# green_miss_a_turn
# green_reverse
# yellow_pick_up_2
# red_reverse
# yellow_wild
# green_7
# red_miss_a_turn
# green_miss_a_turn
# red_reverse
# blue_1
# yellow_pick_up_2
# yellow_wild
# blue_pick_up_2
# green_pick_up_2
# yellow_pick_up_4
# green_1
# yellow_3
# green_pick_up_2
# green_reverse
# blue_reverse
# yellow_4
# red_reverse
# yellow_5
# red_wild
# blue_reverse
# green_pick_up_2
# blue_pick_up_4
# red_miss_a_turn
# blue_pick_up_2
# blue_miss_a_turn
# blue_2
# yellow_miss_a_turn
# red_wild
# green_wild
# yellow_wild
# green_9
# blue_10
# blue_pick_up_2
# red_1
# green_pick_up_2
# red_7
# blue_miss_a_turn
# red_reverse
# green_miss_a_turn
# red_pick_up_2
# green_wild
# yellow_miss_a_turn
# yellow_miss_a_turn
# yellow_reverse
# blue_3
# green_pick_up_2
# red_10
# yellow_pick_up_2
# green_2
# yellow_reverse
# red_pick_up_4
# red_reverse
# red_3
# green_reverse
# green_miss_a_turn
# blue_wild
# yellow_miss_a_turn
# yellow_10
# yellow_reverse
# green_8
# blue_pick_up_2
# blue_wild
# blue_7
# green_4
# yellow_reverse
# blue_miss_a_turn
# red_reverse
# red_4
# green_reverse
# blue_miss_a_turn
# red_reverse
# yellow_8
# green_pick_up_2
# red_2
# yellow_pick_up_2
# blue_wild
# red_miss_a_turn
# blue_9
# yellow_reverse
# yellow_1
# blue_8
# yellow_7
# red_pick_up_4
# yellow_reverse
# green_pick_up_4
# green_reverse
# red_pick_up_2
# yellow_wild
# red_miss_a_turn
# red_6
# red_pick_up_2
# blue_miss_a_turn
# yellow_miss_a_turn
# yellow_2
# yellow_reverse
# red_8
# blue_pick_up_2
# green_wild
# red_pick_up_2
# blue_reverse
# blue_reverse
# green_miss_a_turn
# red_miss_a_turn
# red_pick_up_2
# blue_miss_a_turn
# green_miss_a_turn
# red_wild
# blue_pick_up_2
# yellow_miss_a_turn
# yellow_pick_up_4
# blue_pick_up_2
# blue_5
# green_pick_up_4
# yellow_pick_up_2
# green_5
# yellow_pick_up_4
# yellow_reverse
# green_6
# green_pick_up_2
# yellow_pick_up_2
# red_reverse
# green_pick_up_4
# green_pick_up_2
# blue_reverse
# yellow_pick_up_2
# red_5
# yellow_6
# red_pick_up_2
# red_pick_up_4
# blue_pick_up_2
# blue_wild
# red_9
# red_wild
# red_miss_a_turn
# green_pick_up_4
# green_reverse
# red_pick_up_2
# green_miss_a_turn
# yellow_miss_a_turn
# red_miss_a_turn
# yellow_pick_up_4
# green_wild
# green_reverse
# blue_miss_a_turn
# blue_pick_up_4
# green_reverse
# blue_6
# yellow_pick_up_2
# green_3
# blue_4
# green_miss_a_turn
# blue_pick_up_4
# red_pick_up_2
# blue_pick_up_4
# yellow_9
# blue_miss_a_turn
# red_miss_a_turn
# yellow_miss_a_turn
# blue_reverse
# red_pick_up_4
# red_pick_up_4
