# %%
import random
class Card:
#######__init__ means instatiating the object as it's created

    def __init__(self,colour,number):
  #attribute /storage
        self.colour = colour
        self.number =number
        print(colour,number)
    def __str__(self):
        return f"{self.colour}_{self.number}"
    
class WildCard:
    def __init__(self, colour,action):
        self.colour = colour
        self.action = action

    def __str__(self):
        return f"{self.colour}_{self.action}"

# %%
###########  CREATE THE INITAL DECK  ########################

class Deck:
    def __init__(self):
        self.pack = []

    def create_deck(self):
        colours = ["red", "blue", "green", "yellow"]
        numbers = list(range(1, 10))
        actions = ["pick_up_2","miss_a_turn", "reverse"]
        special_wild_cards = ["wild", "pick_up_4"]
########### ADD NORMAL CARDS ##############################

        for colour in colours:
            for i in range(2):
                for number in numbers:
                    new_card = Card(colour, number)
                    self.pack.append(new_card)
        
            new_card = Card(colour, 0) 
            self.pack.append(new_card)
            print(f"Deck has {len(self.pack)} cards after adding normal cards.")
              #print(self.pack)
         
########### ADD WILD CARDS ###############################

        for wild_card_type in actions:
            for colour in colours:
                for i in range(2):
                    wild_card= WildCard(colour, wild_card_type)
                    self.pack.append(wild_card)
                    print(f"Deck has {len(self.pack)} cards after adding action cards: {wild_card}")   

        for special_wild_card in special_wild_cards:
            for colour in colours:
                wild_card = WildCard(colour, special_wild_card)
                self.pack.append(wild_card)
                print(f"Deck has {len(self.pack)} cards after adding special wild cards: {wild_card}")
    ###########Shuffle########
    def shuffle(self):
        random.shuffle(self.pack)

    #######  DRAW CARD #############
    def draw_card(self):
        if not self.is_empty():
            return self.pack.pop()
        else:
            print("The deck is empty.")
            return None

    def is_empty(self):
        return len(self.pack) == 0

# %%
initial_pack =Deck()
initial_pack.create_deck()
print("these are shuffled")
initial_pack.shuffle()
for shuffledcards in initial_pack.pack:  ##show shuffled pack###
    print(shuffledcards)
# Out:
# red 1
# red 2
# red 3
# red 4
# red 5
# red 6
# red 7
# red 8
# red 9
# red 1
# red 2
# red 3
# red 4
# red 5
# red 6
# red 7
# red 8
# red 9
# red 0
# Deck has 19 cards after adding normal cards.
# blue 1
# blue 2
# blue 3
# blue 4
# blue 5
# blue 6
# blue 7
# blue 8
# blue 9
# blue 1
# blue 2
# blue 3
# blue 4
# blue 5
# blue 6
# blue 7
# blue 8
# blue 9
# blue 0
# Deck has 38 cards after adding normal cards.
# green 1
# green 2
# green 3
# green 4
# green 5
# green 6
# green 7
# green 8
# green 9
# green 1
# green 2
# green 3
# green 4
# green 5
# green 6
# green 7
# green 8
# green 9
# green 0
# Deck has 57 cards after adding normal cards.
# yellow 1
# yellow 2
# yellow 3
# yellow 4
# yellow 5
# yellow 6
# yellow 7
# yellow 8
# yellow 9
# yellow 1
# yellow 2
# yellow 3
# yellow 4
# yellow 5
# yellow 6
# yellow 7
# yellow 8
# yellow 9
# yellow 0
# Deck has 76 cards after adding normal cards.
# Deck has 77 cards after adding action cards: red_pick_up_2
# Deck has 78 cards after adding action cards: red_pick_up_2
# Deck has 79 cards after adding action cards: blue_pick_up_2
# Deck has 80 cards after adding action cards: blue_pick_up_2
# Deck has 81 cards after adding action cards: green_pick_up_2
# Deck has 82 cards after adding action cards: green_pick_up_2
# Deck has 83 cards after adding action cards: yellow_pick_up_2
# Deck has 84 cards after adding action cards: yellow_pick_up_2
# Deck has 85 cards after adding action cards: red_miss_a_turn
# Deck has 86 cards after adding action cards: red_miss_a_turn
# Deck has 87 cards after adding action cards: blue_miss_a_turn
# Deck has 88 cards after adding action cards: blue_miss_a_turn
# Deck has 89 cards after adding action cards: green_miss_a_turn
# Deck has 90 cards after adding action cards: green_miss_a_turn
# Deck has 91 cards after adding action cards: yellow_miss_a_turn
# Deck has 92 cards after adding action cards: yellow_miss_a_turn
# Deck has 93 cards after adding action cards: red_reverse
# Deck has 94 cards after adding action cards: red_reverse
# Deck has 95 cards after adding action cards: blue_reverse
# Deck has 96 cards after adding action cards: blue_reverse
# Deck has 97 cards after adding action cards: green_reverse
# Deck has 98 cards after adding action cards: green_reverse
# Deck has 99 cards after adding action cards: yellow_reverse
# Deck has 100 cards after adding action cards: yellow_reverse
# Deck has 101 cards after adding special wild cards: red_wild
# Deck has 102 cards after adding special wild cards: blue_wild
# Deck has 103 cards after adding special wild cards: green_wild
# Deck has 104 cards after adding special wild cards: yellow_wild
# Deck has 105 cards after adding special wild cards: red_pick_up_4
# Deck has 106 cards after adding special wild cards: blue_pick_up_4
# Deck has 107 cards after adding special wild cards: green_pick_up_4
# Deck has 108 cards after adding special wild cards: yellow_pick_up_4
# these are shuffled
# red_wild
# blue_3
# blue_wild
# yellow_6
# green_1
# blue_pick_up_2
# yellow_0
# blue_6
# blue_9
# blue_8
# red_pick_up_4
# blue_2
# blue_7
# yellow_8
# yellow_2
# red_2
# blue_6
# yellow_3
# green_9
# red_pick_up_2
# blue_1
# green_miss_a_turn
# yellow_6
# yellow_2
# blue_5
# blue_0
# yellow_5
# red_miss_a_turn
# green_2
# blue_pick_up_2
# yellow_9
# red_8
# blue_7
# red_0
# green_pick_up_4
# blue_9
# red_5
# yellow_pick_up_2
# green_pick_up_2
# red_7
# yellow_7
# blue_miss_a_turn
# blue_2
# red_2
# red_reverse
# red_3
# red_4
# green_2
# green_wild
# yellow_7
# green_3
# blue_miss_a_turn
# red_6
# blue_reverse
# red_6
# yellow_pick_up_4
# red_8
# green_5
# yellow_1
# yellow_3
# green_reverse
# red_3
# blue_4
# red_reverse
# blue_1
# red_1
# red_pick_up_2
# green_5
# green_0
# blue_8
# yellow_reverse
# green_8
# yellow_miss_a_turn
# blue_reverse
# green_7
# blue_3
# green_3
# yellow_miss_a_turn
# green_6
# red_9
# yellow_pick_up_2
# red_5
# red_1
# red_miss_a_turn
# green_pick_up_2
# yellow_reverse
# yellow_1
# red_9
# green_miss_a_turn
# yellow_wild
# red_4
# blue_pick_up_4
# yellow_4
# yellow_4
# blue_5
# green_reverse
# green_8
# green_4
# blue_4
# green_9
# green_1
# red_7
# green_7
# yellow_8
# green_4
# yellow_5
# green_6
# yellow_9

# %%
######Deal to players########
class Player:
    def __init__(self, name):
        self.name = name
        self.hand = [] #needs to be a list of cards
        #self.turn = turn
    def __str__(self, ) -> str:
        return self.name

num_players = int(input("Enter the number of players: "))
players = [Player(f"player{i+1}") for i in range(num_players)]

for _ in range(7):  # Loop for each card to be dealt
    for player in players:
        drawn_card = initial_pack.draw_card()
        if drawn_card:
            player.hand.append(drawn_card)

for player in players:
    print(f"{player.name}'s hand: {[str(card) for card in player.hand]}")
# Out:
# Enter the number of players: 2
# player1's hand: ['yellow_9', 'yellow_5', 'yellow_8', 'red_7', 'green_9', 'green_4', 'green_reverse']
# player2's hand: ['green_6', 'green_4', 'green_7', 'green_1', 'blue_4', 'green_8', 'blue_5']
