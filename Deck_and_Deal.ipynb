# %%
import random
random.seed(10)
class Card:
#######__init__ means instatiating the object as it's created

    def __init__(self,colour,number):
  #attribute /storage
        self.colour = colour
        self.number =number
        print(colour,number)
    def __str__(self):
        return f"{self.colour}_{self.number}"
    
class WildCard:
    def __init__(self, colour,action):
        self.colour = colour
        self.action = action

    def __str__(self):
        return f"{self.colour}_{self.action}"
    
class SpecialWildCard:
    def __init__(self,action):
        self.action = action

    def __str__(self):
        return f"{self.action}"

# %%
###########  CREATE THE INITAL DECK  ########################

class Deck:
    def __init__(self):
        self.pack = []
        

    def create_deck(self):
        colours = ["red", "blue", "green", "yellow"]
        numbers = list(range(1, 10))
        actions = ["pick_up_2","miss_a_turn", "reverse"]
        special_wild_cards = ["wild", "pick_up_4"]
########### ADD NORMAL CARDS ##############################

        for colour in colours:
            for i in range(2):
                for number in numbers:
                    new_card = Card(colour, number)
                    self.pack.append(new_card)
        
            new_card = Card(colour, 0) 
            self.pack.append(new_card)
            print(f"Deck has {len(self.pack)} cards after adding normal cards.")
              #print(self.pack)
         
########### ADD WILD CARDS ###############################

        for wild_card_type in actions:
            for colour in colours:
                for i in range(2):
                    wild_card= WildCard(colour, wild_card_type)
                    self.pack.append(wild_card)
                    print(f"Deck has {len(self.pack)} cards after adding action cards: {wild_card}")   

        for special_wild_card in special_wild_cards:
            for i in range(4):
                wild_card = SpecialWildCard(special_wild_card)
                self.pack.append(wild_card)
                print(f"Deck has {len(self.pack)} cards after adding special wild cards: {wild_card}")
    ###########Shuffle########
    def shuffle(self):
        random.shuffle(self.pack)

    #######  DRAW CARD #############
    def draw_card(self):
        if not self.is_empty():
            return self.pack.pop()
        else:
            print("The deck is empty.")
            return None

    def is_empty(self):
        return len(self.pack) == 0

# %%
initial_pack =Deck()
initial_pack.create_deck()
print("these are shuffled")
initial_pack.shuffle()
for shuffledcards in initial_pack.pack:  ##show shuffled pack###
    print(shuffledcards)
# Out:
# red 1
# red 2
# red 3
# red 4
# red 5
# red 6
# red 7
# red 8
# red 9
# red 1
# red 2
# red 3
# red 4
# red 5
# red 6
# red 7
# red 8
# red 9
# red 0
# Deck has 19 cards after adding normal cards.
# blue 1
# blue 2
# blue 3
# blue 4
# blue 5
# blue 6
# blue 7
# blue 8
# blue 9
# blue 1
# blue 2
# blue 3
# blue 4
# blue 5
# blue 6
# blue 7
# blue 8
# blue 9
# blue 0
# Deck has 38 cards after adding normal cards.
# green 1
# green 2
# green 3
# green 4
# green 5
# green 6
# green 7
# green 8
# green 9
# green 1
# green 2
# green 3
# green 4
# green 5
# green 6
# green 7
# green 8
# green 9
# green 0
# Deck has 57 cards after adding normal cards.
# yellow 1
# yellow 2
# yellow 3
# yellow 4
# yellow 5
# yellow 6
# yellow 7
# yellow 8
# yellow 9
# yellow 1
# yellow 2
# yellow 3
# yellow 4
# yellow 5
# yellow 6
# yellow 7
# yellow 8
# yellow 9
# yellow 0
# Deck has 76 cards after adding normal cards.
# Deck has 77 cards after adding action cards: red_pick_up_2
# Deck has 78 cards after adding action cards: red_pick_up_2
# Deck has 79 cards after adding action cards: blue_pick_up_2
# Deck has 80 cards after adding action cards: blue_pick_up_2
# Deck has 81 cards after adding action cards: green_pick_up_2
# Deck has 82 cards after adding action cards: green_pick_up_2
# Deck has 83 cards after adding action cards: yellow_pick_up_2
# Deck has 84 cards after adding action cards: yellow_pick_up_2
# Deck has 85 cards after adding action cards: red_miss_a_turn
# Deck has 86 cards after adding action cards: red_miss_a_turn
# Deck has 87 cards after adding action cards: blue_miss_a_turn
# Deck has 88 cards after adding action cards: blue_miss_a_turn
# Deck has 89 cards after adding action cards: green_miss_a_turn
# Deck has 90 cards after adding action cards: green_miss_a_turn
# Deck has 91 cards after adding action cards: yellow_miss_a_turn
# Deck has 92 cards after adding action cards: yellow_miss_a_turn
# Deck has 93 cards after adding action cards: red_reverse
# Deck has 94 cards after adding action cards: red_reverse
# Deck has 95 cards after adding action cards: blue_reverse
# Deck has 96 cards after adding action cards: blue_reverse
# Deck has 97 cards after adding action cards: green_reverse
# Deck has 98 cards after adding action cards: green_reverse
# Deck has 99 cards after adding action cards: yellow_reverse
# Deck has 100 cards after adding action cards: yellow_reverse
# Deck has 101 cards after adding special wild cards: wild
# Deck has 102 cards after adding special wild cards: wild
# Deck has 103 cards after adding special wild cards: wild
# Deck has 104 cards after adding special wild cards: wild
# Deck has 105 cards after adding special wild cards: pick_up_4
# Deck has 106 cards after adding special wild cards: pick_up_4
# Deck has 107 cards after adding special wild cards: pick_up_4
# Deck has 108 cards after adding special wild cards: pick_up_4
# these are shuffled
# wild
# blue_2
# yellow_4
# red_0
# yellow_2
# yellow_6
# red_miss_a_turn
# pick_up_4
# green_3
# red_4
# yellow_9
# green_5
# yellow_8
# yellow_pick_up_2
# yellow_4
# blue_pick_up_2
# red_4
# yellow_1
# red_8
# green_7
# green_9
# red_9
# blue_3
# green_pick_up_2
# green_4
# green_3
# red_5
# red_3
# green_6
# blue_7
# green_2
# wild
# red_7
# red_8
# green_6
# blue_5
# green_pick_up_2
# blue_reverse
# yellow_miss_a_turn
# yellow_5
# blue_7
# yellow_7
# pick_up_4
# yellow_9
# blue_1
# yellow_miss_a_turn
# green_1
# red_3
# red_7
# wild
# red_6
# red_2
# blue_5
# red_reverse
# blue_0
# red_reverse
# blue_reverse
# yellow_7
# blue_9
# blue_1
# yellow_reverse
# green_5
# green_reverse
# yellow_3
# red_pick_up_2
# red_miss_a_turn
# blue_6
# yellow_0
# wild
# red_1
# green_miss_a_turn
# green_reverse
# green_0
# blue_3
# blue_pick_up_2
# blue_miss_a_turn
# green_miss_a_turn
# green_1
# blue_4
# yellow_2
# blue_6
# blue_9
# blue_miss_a_turn
# green_2
# green_8
# red_pick_up_2
# red_9
# green_7
# red_6
# green_9
# blue_4
# red_1
# green_4
# yellow_reverse
# yellow_1
# pick_up_4
# blue_2
# yellow_pick_up_2
# blue_8
# yellow_6
# yellow_3
# blue_8
# red_2
# pick_up_4
# yellow_5
# green_8
# red_5
# yellow_8

# %%
class Player:
    def __init__(self, number):
        self.number = number
        self.hand = [] #needs to be a list of cards
        
        #self.turn = turn
    def __str__(self, ) -> str:
        return self.number

class startGame:
    def __init__(self):
        self.discard_pile = []
        self.players = [] #keep a list of players
        self.current_player_index = 0
        
        
    def deal(self):
        num_players = int(input("Enter the number of players: "))
        self.players = [Player(f"player{i+1}") for i in range(0,num_players)]
        
##Deal to players########

        for _ in range(7):  # Loop for each card to be dealt
            for player in self.players:
                drawn_card = initial_pack.draw_card()
                if drawn_card:
                    player.hand.append(drawn_card)

            #def start_game(self):
        for player in self.players:
            player.hand=[card for card in player.hand]
            print(f"{player.number}'s hand: {[str(card) for card in player.hand]}")
    
    def discard(self):
        while True:
            top_card = initial_pack.draw_card()
            #self.discard_pile.append(str(top_card))
            self.discard_pile.append(top_card)
            print(f"Top card on the discard pile: {top_card}")
            ###just checking it actually went there ####
            #print(f"this is the whole discard pile:{self.discard_pile}")

            if type(top_card) == WildCard and top_card.action in ["wild", "pick_up_4"]:
                    print(f"Unsuitable start card (wild card), flip again")
            else:
                    #print(f"Top card on the discard pile is: {top_card}")
                break
##function to play a card###
    def play_card(self, player):
        #player =game1.players.index
        current_player =(game1.players[self.current_player_index])
        current_player_hand=(game1.players[self.current_player_index].hand)
        print(f"{current_player}, it is your turn, which card would you like to play from your hand: {', '.join(map(str, current_player_hand))}")
       # print(current_player_hand)
##player chooses a card to play
        chosen_card=int(input("Enter the index of the card you want to play card"))
        #print(current_player_hand[choosen_card])
        played_card=current_player_hand[chosen_card]
        discarded_card_in_play= self.discard_pile[-1]
##check for colour or number match
        if (str(played_card) == "wild" or
            (hasattr(played_card, 'colour') and played_card.colour == discarded_card_in_play.colour) or 
            (hasattr(played_card, 'number') and played_card.number == discarded_card_in_play.number)):

## handle what to do if it's a wildcqrd played
        #ask user to choose a colour

            #print(self.discard_pile[-1].colour)
## add chosen card to the discard list
            self.discard_pile.append(played_card)
            print(f"Top card on the discard pile: {self.discard_pile[-1]}")
            discarded_card_in_play=self.discard_pile[-1]
            #print(discarded_card_in_play)
#remove card from the players hand##
            current_player_hand.pop(chosen_card)
            #print(f"{current_player} it is your turn, which card would you like to play from your hand: {','.join(map(str,current_player_hand))} ")
        else:
            print("can't play that card")
            ##need to send back to choose another card
            
##Move to the next player##
        game1.current_player_index = (game1.current_player_index + 1) % len(game1.players)
        #next_player = game1.players[next_player_index]
        #current_player = self.players[next_player]
        print(game1.current_player_index)
        game1.play_card(game1.players)
        #current_player_hand=(game1.players[0].hand)

# %%
 
  #player_turn =player.number

   
       # print(f"Player {player.number}'s hand: {[str(card) for card in player.hand]}")

# ##conditions of play based on discard card##
    ##player plays hand##
##check played card is valid##
    ##needs to be the same colour, or wild##
    ## if pick up 2##
    ## if pick up 4##
    ## if wild##
    ## if reverse##

# %%
#startGame()
initial_pack.shuffle()
for shuffledcards in initial_pack.pack:  ##show shuffled pack###
    print(shuffledcards) 
game1=startGame()
game1.deal()
game1.discard()
game1.play_card(game1.players)
# Out:
# yellow_miss_a_turn
# blue_4
# blue_8
# red_7
# green_9
# red_miss_a_turn
# red_5
# green_5
# green_3
# green_pick_up_2
# yellow_4
# yellow_7
# blue_miss_a_turn
# red_8
# green_pick_up_2
# red_5
# blue_reverse
# red_6
# green_4
# red_0
# blue_6
# green_7
# red_6
# blue_5
# yellow_9
# blue_3
# blue_0
# yellow_5
# yellow_pick_up_2
# blue_9
# yellow_5
# pick_up_4
# blue_2
# green_4
# blue_4
# yellow_4
# blue_2
# blue_pick_up_2
# yellow_reverse
# pick_up_4
# yellow_3
# red_3
# red_reverse
# blue_5
# green_miss_a_turn
# red_4
# green_1
# green_0
# green_6
# red_7
# green_7
# red_3
# yellow_6
# red_pick_up_2
# red_2
# blue_9
# blue_miss_a_turn
# blue_7
# yellow_miss_a_turn
# yellow_reverse
# red_4
# green_8
# blue_3
# red_miss_a_turn
# red_pick_up_2
# green_miss_a_turn
# wild
# yellow_2
# yellow_2
# yellow_8
# blue_reverse
# green_reverse
# green_8
# green_2
# pick_up_4
# wild
# blue_1
# yellow_pick_up_2
# yellow_8
# red_reverse
# yellow_1
# blue_8
# blue_1
# green_reverse
# red_9
# green_3
# yellow_1
# green_1
# green_5
# blue_6
# green_6
# yellow_0
# green_2
# red_9
# yellow_3
# wild
# green_9
# blue_pick_up_2
# red_2
# yellow_7
# red_8
# yellow_9
# wild
# blue_7
# pick_up_4
# yellow_6
# red_1
# red_1
# Enter the number of players: 3
# player1's hand: ['red_1', 'pick_up_4', 'yellow_9', 'red_2', 'wild', 'green_2', 'blue_6']
# player2's hand: ['red_1', 'blue_7', 'red_8', 'blue_pick_up_2', 'yellow_3', 'yellow_0', 'green_5']
# player3's hand: ['yellow_6', 'wild', 'yellow_7', 'green_9', 'red_9', 'green_6', 'green_1']
# Top card on the discard pile: yellow_1
# player1, it is your turn, which card would you like to play from your hand: red_1, pick_up_4, yellow_9, red_2, wild, green_2, blue_6
# Enter the index of the card you want to play card0
# Top card on the discard pile: red_1
# 1
# player2, it is your turn, which card would you like to play from your hand: red_1, blue_7, red_8, blue_pick_up_2, yellow_3, yellow_0, green_5
# Enter the index of the card you want to play card0
# Top card on the discard pile: red_1
# 2
# player3, it is your turn, which card would you like to play from your hand: yellow_6, wild, yellow_7, green_9, red_9, green_6, green_1
# Enter the index of the card you want to play card1
# Top card on the discard pile: wild
# 0
# player1, it is your turn, which card would you like to play from your hand: pick_up_4, yellow_9, red_2, wild, green_2, blue_6

# %%
#current_player=player()
#game1.play_card(game1.players[0])
