# %%
import random
class Card:
#######__init__ means instatiating the object as it's created

  def __init__(self,colour,number):
  #attribute /storage
    self.colour = colour
    self.number =number
    #print(colour,number)

####### prints out the default string representation of the __main__.Card object at 0x7a8a0c679a20
####### using --str-- function to have it print in text

  def __str__(self):
        return f"{self.colour}_{self.number}"

class WildCard:
  def __init__(self, colour,action):
    self.colour = colour
    self.action = action

  def __str__(self):
    return f"{self.colour}_{self.action}"

###########  CREATE THE INITAL DECK  ########################

class Deck:
  def __init__(self):
        self.pack = []

  def create_deck(self):
        colours = ["red", "blue", "green", "yellow"]
        numbers = list(range(1, 11))
        actions = ["pick_up_2","miss_a_turn", "reverse"]
        special_wild_cards = ["wild", "pick_up_4"]

 #for number in range(1, 11):
            #self.pack.append(number)



########### ADD NORMAL CARDS ##############################
        for colour in colours:
            for number in numbers:
                new_card = Card(colour, number)
                self.pack.append(new_card)
        #print(self.pack)

########### ADD WILD CARDS ###############################

        for wild_card_type in actions:
          for colour in colours:
            for _ in range(2):

                    wild_card= WildCard(colour, wild_card_type)
                    self.pack.append(wild_card)



        for special_wild_card in special_wild_cards:
            for colour in colours:
                wild_card = WildCard(colour, special_wild_card)
                self.pack.append(wild_card)


####### SHUFFLE FUNCTION ###########

  def shuffle(self):
        random.shuffle(self.pack)
        print(self.pack)

# %%
###############test area################
#test_card =Card("yellow","9")
initial_pack =Deck()
initial_pack.create_deck()
initial_pack.shuffle()
for card in initial_pack.pack:
    print(card)
# Out:
# [<__main__.WildCard object at 0x7f06f4965d80>, <__main__.Card object at 0x7f06f4967ca0>, <__main__.Card object at 0x7f06f4966e60>, <__main__.Card object at 0x7f06f4967be0>, <__main__.WildCard object at 0x7f06f4965cc0>, <__main__.WildCard object at 0x7f06f4965ed0>, <__main__.Card object at 0x7f06f4966d40>, <__main__.WildCard object at 0x7f06f4966170>, <__main__.Card object at 0x7f06f4966b00>, <__main__.WildCard object at 0x7f06f4967760>, <__main__.Card object at 0x7f06f4966c20>, <__main__.Card object at 0x7f06f4966a70>, <__main__.WildCard object at 0x7f06f4966200>, <__main__.WildCard object at 0x7f06f4966b30>, <__main__.Card object at 0x7f06f4964c10>, <__main__.Card object at 0x7f06f4966bf0>, <__main__.Card object at 0x7f06f49664a0>, <__main__.Card object at 0x7f06f4964bb0>, <__main__.Card object at 0x7f06f4966aa0>, <__main__.WildCard object at 0x7f06f4965f30>, <__main__.Card object at 0x7f06f4967f40>, <__main__.Card object at 0x7f06f4966ef0>, <__main__.WildCard object at 0x7f06f4966050>, <__main__.Card object at 0x7f06f4964a30>, <__main__.WildCard object at 0x7f06f4965ea0>, <__main__.WildCard object at 0x7f06f49667a0>, <__main__.WildCard object at 0x7f06f4966560>, <__main__.WildCard object at 0x7f06f4966800>, <__main__.WildCard object at 0x7f06f49674f0>, <__main__.Card object at 0x7f06f4966470>, <__main__.Card object at 0x7f06f4966f20>, <__main__.Card object at 0x7f06f4967430>, <__main__.Card object at 0x7f06f4964700>, <__main__.Card object at 0x7f06f49646a0>, <__main__.WildCard object at 0x7f06f49676a0>, <__main__.Card object at 0x7f06f4966c80>, <__main__.Card object at 0x7f06f4967520>, <__main__.WildCard object at 0x7f06f4965de0>, <__main__.Card object at 0x7f06f4964e50>, <__main__.Card object at 0x7f06f4967c70>, <__main__.WildCard object at 0x7f06f4966890>, <__main__.WildCard object at 0x7f06f4966980>, <__main__.Card object at 0x7f06f4966290>, <__main__.WildCard object at 0x7f06f49665c0>, <__main__.WildCard object at 0x7f06f49660e0>, <__main__.Card object at 0x7f06f49675b0>, <__main__.Card object at 0x7f06f4966f50>, <__main__.WildCard object at 0x7f06f4965f90>, <__main__.Card object at 0x7f06f49649a0>, <__main__.WildCard object at 0x7f06f4966680>, <__main__.Card object at 0x7f06f49662c0>, <__main__.Card object at 0x7f06f4966dd0>, <__main__.Card object at 0x7f06f4967940>, <__main__.Card object at 0x7f06f4966320>, <__main__.Card object at 0x7f06f4964e80>, <__main__.WildCard object at 0x7f06f4965cf0>, <__main__.WildCard object at 0x7f06f4965f00>, <__main__.WildCard object at 0x7f06f4966710>, <__main__.Card object at 0x7f06f4964dc0>, <__main__.WildCard object at 0x7f06f4966e90>, <__main__.Card object at 0x7f06f4967f70>, <__main__.Card object at 0x7f06f4967bb0>, <__main__.WildCard object at 0x7f06f4966650>, <__main__.Card object at 0x7f06f4966e00>, <__main__.WildCard object at 0x7f06f4965d20>, <__main__.WildCard object at 0x7f06f4966110>, <__main__.Card object at 0x7f06f4967b80>, <__main__.Card object at 0x7f06f49663e0>, <__main__.WildCard object at 0x7f06f4965c30>, <__main__.WildCard object at 0x7f06f4966b60>, <__main__.WildCard object at 0x7f06f49661d0>, <__main__.Card object at 0x7f06f49672e0>]
# red_reverse
# red_7
# green_9
# blue_10
# red_reverse
# yellow_miss_a_turn
# green_4
# red_miss_a_turn
# yellow_2
# yellow_reverse
# green_7
# yellow_10
# green_miss_a_turn
# red_pick_up_2
# blue_2
# green_6
# yellow_5
# blue_3
# yellow_9
# yellow_pick_up_2
# red_9
# green_2
# yellow_pick_up_2
# blue_1
# blue_reverse
# blue_wild
# yellow_pick_up_4
# yellow_wild
# blue_miss_a_turn
# yellow_3
# green_10
# red_3
# blue_6
# blue_5
# yellow_reverse
# green_8
# red_4
# yellow_miss_a_turn
# red_6
# red_8
# red_wild
# green_reverse
# yellow_6
# green_pick_up_4
# blue_pick_up_2
# red_2
# yellow_1
# blue_miss_a_turn
# blue_7
# blue_pick_up_4
# yellow_7
# green_3
# red_5
# yellow_8
# red_1
# blue_reverse
# red_miss_a_turn
# red_pick_up_4
# blue_4
# red_pick_up_2
# red_10
# blue_8
# green_wild
# green_5
# green_miss_a_turn
# green_pick_up_2
# blue_9
# yellow_4
# green_reverse
# blue_pick_up_2
# green_pick_up_2
# green_1
